# %%
from scipy.stats import wilcoxon

# Τα scores από τους ίδιους 11 αλγορίθμους σε 2 διαφορετικά datasets
accuracy_before = [0.86, 0.69, 0.90, 0.67, 0.82, 0.85, 0.85, 0.86, 0.79, 0.85, 0.94]
accuracy_after =  [0.96, 0.58, 0.95, 0.93, 0.94, 0.96, 0.96, 0.96, 0.80, 0.95, 0.96]
precision_before= [0.88, 1.00, 0.92, 0.54, 0.88, 0.88, 0.88, 0.89, 0.90, 0.88, 0.90]
precision_after= [0.85, 1.00, 0.85, 0.66, 0.85, 0.83, 0.79, 0.85, 0.78, 0.85, 0.85]
recall_before= [0.90, 0.07, 0.84, 0.29, 0.77, 0.87, 0.86, 0.97, 0.42, 0.86, 0.97]
recall_after= [0.96, 0.11, 0.98, 0.83, 0.85, 0.94, 0.96, 0.94, 0.60, 0.94, 0.98]
f1_before= [0.86, 0.12, 0.86, 0.37, 0.78, 0.84, 0.83, 0.84, 0.55, 0.83, 0.91]
f1_after= [0.90, 0.19, 0.91, 0.74, 0.85, 0.88, 0.87, 0.89, 0.67, 0.89, 0.91]

# Wilcoxon signed-rank test
w_stat, p_val_w = wilcoxon(accuracy_after, accuracy_before)
print(f"Wilcoxon test p-value: {p_val_w:.4f}")
w_stat, p_val_w = wilcoxon(precision_after, precision_before)
print(f"Wilcoxon test p-value: {p_val_w:.4f}")
w_stat, p_val_w = wilcoxon(recall_after, recall_before)
print(f"Wilcoxon test p-value: {p_val_w:.4f}")
w_stat, p_val_w = wilcoxon(f1_after, f1_before)
print(f"Wilcoxon test p-value: {p_val_w:.4f}")
# Out:
# Wilcoxon test p-value: 0.0254
# Wilcoxon test p-value: 0.0742
# Wilcoxon test p-value: 0.0029
# Wilcoxon test p-value: 0.0020
